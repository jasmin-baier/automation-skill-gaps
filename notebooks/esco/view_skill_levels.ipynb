# %%
import pandas as pd

# %%
# view skills_with_levels.csv

df = pd.read_csv('skills_with_levels.csv')
df.head()
# Out:
#                          ID  \
# 0  68933872ba407998dac8a24d
# 1  68933872ba407998dac8a24e
# 2  68933872ba407998dac8a24f
# 3  68933872ba407998dac8a250
# 4  68933872ba407998dac8a251
#
#                                            ORIGINURI  \
# 0  http://data.europa.eu/esco/skill/0005c151-5b5a...
# 1  http://data.europa.eu/esco/skill/00064735-8fad...
# 2  http://data.europa.eu/esco/skill/000709ed-2be5...
# 3  http://data.europa.eu/esco/skill/0007bdc2-dd15...
# 4  http://data.europa.eu/esco/skill/00090cc1-1f27...
#
#                                          UUIDHISTORY DEFINITION SCOPENOTE  \
# 0  5e754c1c-6e5c-46b3-b072-d38cb987b240\n76d72d7b...        NaN       NaN
# 1  259a8553-e37a-4b7e-b9a2-54f7a9d6c9d6\n1a640f0a...        NaN       NaN
# 2  b7dc5466-b36c-4b95-a79c-3aa6f30c0971\n3b346847...        NaN       NaN
# 3  39813bcd-7dbb-47cb-9859-6a0a693ddd0d\n7b25a759...        NaN       NaN
# 4  988307b6-fccb-4bdf-a0bc-f1e4e8888bce\nca41bd96...        NaN       NaN
#
# ...
